# %% [markdown]
# <a href="https://colab.research.google.com/github/liberato10/Renaming/blob/main/Renaming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Keep in mind that the filename will likely be different on your computer (especially later in course)

filename ='/content/drive/MyDrive/mortgages (1).csv'

df = pd.read_csv(filename)

# %%
/content/drive/MyDrive/mortgages (1).csv

# %%
# DataFrame before renaming columns

df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
# Approach 1 dictionary substitution using rename method

df = df.rename(columns={'Starting Balance': 'starting_balance',

'Interest Paid': 'interest_paid',

'Principal Paid': 'principal_paid'})

# DataFrame after renaming columns

df.head()
# Out:
#    Month  starting_balance  Repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    New Balance Mortgage Name  Interest Rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
# Approach 2 list replacement

# Even if you want to rename a single column you need to list the rest of the columns

df.columns = ['month',

'starting_balance',

'repayment',

'interest_paid',

'principal_paid',

'new_balance',

'mortgage_name',

'interest_rate']

df.head()
# Out:
#    month  starting_balance  repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#    new_balance mortgage_name  interest_rate
# 0    399313.58       30 Year           0.03
# 1    398625.44       30 Year           0.03
# 2    397935.58       30 Year           0.03
# 3    397243.99       30 Year           0.03
# 4    396550.67       30 Year           0.03

# %%
# Approach 1

df = df.drop(columns=['new_balance'])

df.head()
# Out:
#    month  starting_balance  repayment  interest_paid  principal_paid  \
# 0      1         400000.00    1686.42        1000.00          686.42
# 1      2         399313.58    1686.42         998.28          688.14
# 2      3         398625.44    1686.42         996.56          689.86
# 3      4         397935.58    1686.42         994.83          691.59
# 4      5         397243.99    1686.42         993.10          693.32
#
#   mortgage_name  interest_rate
# 0       30 Year           0.03
# 1       30 Year           0.03
# 2       30 Year           0.03
# 3       30 Year           0.03
# 4       30 Year           0.03

# %%
# Approach 2 use the del command

del df['starting_balance']

df.head()
# Out:
#    month  repayment  interest_paid  principal_paid mortgage_name  \
# 0      1    1686.42        1000.00          686.42       30 Year
# 1      2    1686.42         998.28          688.14       30 Year
# 2      3    1686.42         996.56          689.86       30 Year
# 3      4    1686.42         994.83          691.59       30 Year
# 4      5    1686.42         993.10          693.32       30 Year
#
#    interest_rate
# 0           0.03
# 1           0.03
# 2           0.03
# 3           0.03
# 4           0.03
